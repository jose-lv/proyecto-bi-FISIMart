# %% [markdown]
# #### Celda 1: Instalación de Dependencias Obligatorias

# %%
# Instalación de librerías mediante comandos mágicos de Jupyter
# %pip install pandas numpy Faker mlxtend
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Celda 2: Configuración del Entorno, Directorios y Semilla Reproducible (Semilla: 20)

# %%
import os
import random
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
from faker import Faker

# Configuración estricta de reproducibilidad
SEMILLA = 20
random.seed(SEMILLA)
np.random.seed(SEMILLA)
fake = Faker('es_ES')
Faker.seed(SEMILLA)

# Definición de volúmenes analíticos
N_CLIENTES = 5000
N_PRODUCTOS = 600
N_TIENDAS = 20
N_PROMOCIONES = 40
N_LINEAS_VENTA = 50000

# Creación automatizada de la arquitectura de carpetas del proyecto
os.makedirs("data/raw", exist_ok=True)
os.makedirs("data/processed", exist_ok=True)

print(f"● Entorno FISIMart S.A.C. inicializado con Semilla {SEMILLA}.")
print("● Directorios 'data/raw' y 'data/processed' validados/creados.")
# Out:
# ● Entorno FISIMart S.A.C. inicializado con Semilla 20.
# ● Directorios 'data/raw' y 'data/processed' validados/creados.
